# %% [markdown]
# # 주식가격
#
# **문제 설명**
# 초 단위로 기록된 주식가격이 담긴 배열 prices가 매개변수로 주어질 때, 가격이 떨어지지 않은 기간은 몇 초인지를 return 하도록 solution 함수를 완성하세요.
#
# **제한사항**
# - prices의 각 가격은 1 이상 10,000 이하인 자연수입니다.
# - prices의 길이는 2 이상 100,000 이하입니다.
#
# **입출력 예**
#
# |prices|	return|
# |:--:|:---:|
# |[1, 2, 3, 2, 3]|	[4, 3, 1, 1, 0]|
#
#
# **입출력 예 설명**
#
# - 1초 시점의 ₩1은 끝까지 가격이 떨어지지 않았습니다.
# - 2초 시점의 ₩2은 끝까지 가격이 떨어지지 않았습니다.
# - 3초 시점의 ₩3은 1초뒤에 가격이 떨어집니다. 따라서 1초간 가격이 떨어지지 않은 것으로 봅니다.
# - 4초 시점의 ₩2은 1초간 가격이 떨어지지 않았습니다.
# - 5초 시점의 ₩3은 0초간 가격이 떨어지지 않았습니다.

# %%
from collections import deque

def solution(prices):
    answer = []
    prices = deque(prices)
    
    while prices:
        
        price = prices.popleft()
        stack = [price]

        if len(prices) == 0:
            answer.append(0)
            break

        for next_price in prices: # 나머지 요소에 대해
            # 가격이 떨어진 경우
            if price <= next_price:
                stack.append(next_price)
                
                # 가격이 한번도 떨어지지 않은경우
                if len(stack) - 1 == len(prices):
                    answer.append(len(stack) - 1)
                    break
            else:
                # 가격이 중간에 떨어진 경우
                answer.append(len(stack))
                break
                    
    return answer

# %%
prices = [1, 2, 3, 2, 3]
solution(prices)
# Out:
# [4, 3, 1, 1, 0]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# O(N^2)
from collections import deque

def solution(prices):
    answer = []
    prices = deque(prices)

    while prices:
        curr_price = prices.popleft()
        cnt = 0
        for price in prices:
            if curr_price <= price:
                cnt += 1
            else:
                cnt += 1
                break
        answer.append(cnt)
    return answer

# %%
prices = [1, 2, 3, 2, 3]
solution(prices)
# Out:
# [4, 3, 1, 1, 0]

# %% [markdown]
# ![image.png](attachment:image.png)
