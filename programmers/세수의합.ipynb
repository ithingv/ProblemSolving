# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from itertools import permutations

# %%
nums= [-1, 0, 1, 2, -1, -4]
for comb in combinations(nums, 3):
    if sum(comb) == 0:
        print(comb)
# Out:
# (-1, 0, 1)
# (-1, 2, -1)
# (0, 1, -1)
